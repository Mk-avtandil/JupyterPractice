# %% [markdown]
# ### 1. На вход подается число от 0 до 1000.
#
# Если число от 0 до 99, программа должна вернуть "Ваше число меньше 100".
#
# Если число от 100 до 499, программа должна вернуть "Ваше число меньше 500, но больше 100".
#
# Если число от 500 до 1000, программа должна вернуть "Ваше число меньше 1000, но больше 500".

# %%
n = int(input())

if n > 0 and n < 100:
    print("Ваше число меньше 100")
elif n >= 100 and n < 500:
    print("Ваше число меньше 500, но больше 100")
elif n >= 500 and n < 1000:
    print("Ваше число меньше 1000, но больше 500")
# Out:
# 100
# Ваше число меньше 500, но больше 100

# %% [markdown]
# ### 2. На вход подаются длина и ширина прямоугольника. Если они равны, выведите, что это квадрат. Иначе "это прямоугольник".
#
# **Пример**
#
# `input`
#
# `5`
#
# `3`
#
# `output`
#
# `"Это прямоугольник"`

# %%
a = int(input())
b = int(input())

if a == b:
    print("Это квадрат")
else:
    print("Это прямоугольник")
# Out:
# 5
# 3
# Это прямоугольник

# %% [markdown]
# ### 3. Программа для выставления оценок. На вход подается количество баллов от 0 до 100. Выставите оценку по указанной ниже системе.
#
# Имеется следующая система выставления оценок:
#
# 1. ниже 25 - F
# 2. от 25 до 45 - E
# 3. от 45 до 50 - D
# 4. от 50 до 60 - C
# 5. от 60 до 80 - B
# 6. Выше 80 - A

# %%
bal = int(input())

if bal < 25:
    print("F")
elif bal >= 25 and bal < 45:
    print("E")
elif bal >= 45 and bal < 50:
    print("D")
elif bal >= 50 and bal < 60:
    print("C")
elif bal >= 60 and bal < 80:
    print("B")
elif bal > 80:
    print("A")
# Out:
# 50
# C

# %% [markdown]
# ### 4. Собака или кошка?
#
# На вход подается слово "dog" или "cat".
#
# Если "dog", выведите "bark"
#
# Если "cat", выведите "meow"

# %%
word = input()
res = lambda x: 'bark' if x == 'dog' else ('meow' if x == 'cat' else 'animal')
print(res(word))
# Out:
# cat
# meow

# %% [markdown]
# ### 5. На вход подается положительное число, определите четное оно или нечетное.
#
# **Пример**
#
# `input`
#
# `5`
#
# `output`
#
# `"Это число нечетное"`

# %%
n = int(input())
res = lambda x: "Это число нечетное" if n % 2 != 0 else "Число четное"
print(res(n))
# Out:
# 6
# Число четное

# %% [markdown]
# ### 6. Программа получает на вход последовательность целых неотрицательных чисел по одному. Последовательность завершается числом 0, при считывании которого программа должна закончить свою работу и вывести количество **нечетных** членов последовательности (не считая завершающего числа 0).
#
# **Пример**
#
# `input`
#
# `5`
#
# `2`
#
# `1`
#
# `0`
#
# `output`
#
# `2`

# %%
my_list = []
while True:
    n = int(input())
    if n == 0:
        break
    else:
        my_list.append(n)
cnt = 0
for i in my_list:
    if i % 2 != 0: cnt += 1
print(cnt)
# Out:
# 5
# 2
# 1
# 0
# 2

# %% [markdown]
# ### 7.  На вход подается число, поменяйте знак числа и верните.
# Если оно положительно верните со знаком минус, если отрицательно без знака минус.
#
# **Пример**
#
# `input`
#
# `5`
#
# `output`
#
# `-5`
#
# `input`
#
# `-78`
#
# `output`
#
# `78`

# %%
import math
n = int(input())
res = lambda x: abs(n) if n < 0 else -n
print(res(n))
# Out:
# -78
# 78

# %% [markdown]
# ### 8.  Программа получает на вход последовательность целых неотрицательных чисел по одному. Последовательность завершается числом 0, при считывании которого программа должна закончить свою работу и вывести максимальное и минимальное число в последовательности (не считая завершающего числа 0).
#
# **Пример**
#
# `input`
#
# `5`
#
# `2`
#
# `1`
#
# `3`
#
# `0`
#
# `output`
#
# `максимум: 5`
#
# `минимум: 1`

# %%
my_list = []
while True:
    n = int(input())
    if n == 0:
        break
    else:
        my_list.append(n)
print(f"Max {max(my_list)}")
print(f"Min {min(my_list)}")
# Out:
# 5
# 2
# 1
# 3
# 0
# Max 5
# Min 1

# %% [markdown]
# ### 9. На вход подается 1 или 0. Выведите `True` если 1, иначе `False`.
#
# **Пример**
#
# `input`
#
# `0`
#
# `output`
#
# `False`

# %%
n = int(input())
print(bool(n))
# Out:
# 0
# False

# %% [markdown]
# ### 10. На вход подается целое положительное число. Напечатайте столько же раз слово "hi"
#
# **Пример**
#
# `input`
#
# `5`
#
# `output`
#
# `hi hi hi hi hi`

# %%
n = int(input())
print("hi " * n)
# Out:
# 5
# hi hi hi hi hi

# %% [markdown]
# ###  11. Программа получает на вход последовательность целых неотрицательных чисел по одному. Последовательность завершается числом 0, при считывании которого программа должна закончить свою работу и вывести числа в ряд без пробела (не считая завершающего числа 0).
#
# **Пример**
#
# `input`
#
# `5`
#
# `2`
#
# `1`
#
# `3`
#
# `0`
#
# `output`
#
# `5213`

# %%
my_list = []
while True:
    n = int(input())
    if n == 0:
        break
    else:
        my_list.append(n)
for i in my_list:
    print(i, end='')
# Out:
# 5
# 2
# 1
# 3
# 0
# 5213

# %% [markdown]
# ### 12. Банковские вклады
#
# Вклад в банке составляет `x` рублей. Ежегодно он увеличивается на 10 процентов. Определите, через сколько лет вклад составит не менее `y` рублей.
#
# На вход подается:
#
# `x` - сколько мы положили в начале
#
# `y` - минимум сколько мы хотим получить.

# %%
x = int(input('X: '))
y = int(input('Y: '))
year = 0
while x < y:
    x += int(x / 100 * 10)
    year += 1
print('Понадобится ', year)
# Out:
# X: 100
# Y: 200
# Понадобится  8

# %% [markdown]
# ### 13. Среднее значение последовательности.
#
# Определите среднее значение всех элементов последовательности, завершающейся числом 0.
#
# `Входные данные`
#
# Вводится последовательность целых чисел, оканчивающаяся числом 0 (само число 0 в последовательность не входит, а служит как признак ее окончания.
#
# `Выходные данные`
#
# Выведите ответ на задачу.
#
# `Примеры`
#
# `входные данные`
#
# `1`
#
# `7`
#
# `9`
#
# `0`
#
# `выходные данные`
#
# `5.66666666667`
#
#
# `hint: (1+7+9) / 3 = 5.6667`

# %%
my_list = []
while True:
    n = int(input())
    if n == 0:
        break
    else:
        my_list.append(n)
print(sum(my_list) / len(my_list))
# Out:
# 1
# 7
# 9
# 0
# 5.666666666666667

# %% [markdown]
# 14. Список квадратов
#
# По данному целому числу N распечатайте все квадраты натуральных чисел, не превосходящие N, в порядке возрастания.
#
# `Входные данные`
#
# `50`
#
# `Выходные данные`
#
# `1 4 9 16 25 36 49`

# %%
n = int(input())
i = 1
while i**2 <= n:
    print(i**2)
    i += 1
# Out:
# 50
# 1
# 4
# 9
# 16
# 25
# 36
# 49

# %% [markdown]
# ### 15. Игра, угадай число (улучшение).
#
# Напишите ту же игру угадай число, но теперь угадываемое число будет случайным от 0 до 100 (используйте код ниже для генерации случайного числа).

# %%
import random

myNumber = random.randint(0, 100) # это генерирует случайное число для игры
i = 0
while True:
    n = int(input('Угадайте число от 0 до 100: '))
    if n > myNumber:
        print(">")
    elif n < myNumber:
        print("<")
    else:
        print(f"Вы угадали с {i}й - попытки")
    i += 1
# Out:
# Угадайте число от 0 до 100: 50
# >
# Угадайте число от 0 до 100: 25
# <
# Угадайте число от 0 до 100: 45
# >
# Угадайте число от 0 до 100: 35
# >
# Угадайте число от 0 до 100: 30
# <
# Угадайте число от 0 до 100: 34
# Вы угадали с 5й - попытки
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5087/2864559538.py in <module>
#       4 i = 0
#       5 while True:
# ----> 6     n = int(input('Угадайте число от 0 до 100: '))
#       7     if n > myNumber:
#       8         print(">")
#
# ~/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
